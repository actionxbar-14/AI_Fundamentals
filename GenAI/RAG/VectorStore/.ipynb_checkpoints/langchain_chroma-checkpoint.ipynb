# %%
pip install langchain langchain-community langchain-chroma chromadb pypdf sentence-transformers ollama
# Out:
# Requirement already satisfied: langchain in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.3.18)
# Requirement already satisfied: langchain-community in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.4.2)
# Collecting langchain-chroma
#   Downloading langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting chromadb
#   Downloading chromadb-1.5.9-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: pypdf in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (6.18.0)
# Requirement already satisfied: sentence-transformers in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (6.0.0)
# Requirement already satisfied: ollama in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.6.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain) (1.6.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.3)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.8.0)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.7.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.6.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.5.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.4)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.30.0-cp314-cp314-win_amd64.whl.metadata (5.9 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from chromadb) (0.23.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from chromadb) (4.70.0)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.83.1-cp314-cp314-win_amd64.whl.metadata (3.8 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from chromadb) (0.27.1)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-36.0.3-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.3.0-cp314-cp314-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: transformers<6.0.0,>=5.0.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sentence-transformers) (5.16.1)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.3.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sentence-transformers) (1.28.0)
# Requirement already satisfied: torch>=2.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sentence-transformers) (2.13.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sentence-transformers) (1.9.0)
# Requirement already satisfied: scipy>=1.0.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sentence-transformers) (1.18.1)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (3.32.4)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (1.6.0)
# Requirement already satisfied: colorama in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers) (2026.7.19)
# Requirement already satisfied: safetensors>=0.8.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers) (0.8.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2026.5.1)
# Requirement already satisfied: six>=1.9.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.11-py3-none-any.whl.metadata (474 bytes)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: protobuf>=4.25.8 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (7.36.0)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.75.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.65b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn>=1.1.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn>=1.1.0->sentence-transformers) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn>=1.1.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools>=77.0.3 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=2.2->sentence-transformers) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=2.2->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=2.2->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch>=2.2->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sympy>=1.13.3->torch>=2.2->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.5)
# Requirement already satisfied: httptools>=0.8.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.2.0-cp314-cp314-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->torch>=2.2->sentence-transformers) (3.0.3)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Downloading chromadb-1.5.9-cp39-abi3-win_amd64.whl (23.5 MB)
#    ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/23.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/23.5 MB 2.4 MB/s eta 0:00:10
#    - -------------------------------------- 1.0/23.5 MB 1.8 MB/s eta 0:00:13
#    -- ------------------------------------- 1.6/23.5 MB 2.0 MB/s eta 0:00:12
#    --- ------------------------------------ 1.8/23.5 MB 1.8 MB/s eta 0:00:13
#    --- ------------------------------------ 2.1/23.5 MB 1.7 MB/s eta 0:00:13
#    ---- ----------------------------------- 2.4/23.5 MB 1.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 2.6/23.5 MB 1.8 MB/s eta 0:00:12
#    ----- ---------------------------------- 3.1/23.5 MB 1.7 MB/s eta 0:00:13
#    ----- ---------------------------------- 3.4/23.5 MB 1.8 MB/s eta 0:00:12
#    ------ --------------------------------- 3.7/23.5 MB 1.7 MB/s eta 0:00:12
#    ------ --------------------------------- 3.7/23.5 MB 1.7 MB/s eta 0:00:12
#    ------ --------------------------------- 3.7/23.5 MB 1.7 MB/s eta 0:00:12
#    ------ --------------------------------- 3.7/23.5 MB 1.7 MB/s eta 0:00:12
#    ------ --------------------------------- 3.7/23.5 MB 1.7 MB/s eta 0:00:12
#    ------ --------------------------------- 3.9/23.5 MB 1.2 MB/s eta 0:00:17
#    ------- -------------------------------- 4.2/23.5 MB 1.2 MB/s eta 0:00:17
#    ------- -------------------------------- 4.5/23.5 MB 1.2 MB/s eta 0:00:16
#    -------- ------------------------------- 4.7/23.5 MB 1.2 MB/s eta 0:00:16
#    -------- ------------------------------- 5.0/23.5 MB 1.2 MB/s eta 0:00:16
#    -------- ------------------------------- 5.2/23.5 MB 1.2 MB/s eta 0:00:15
#    --------- ------------------------------ 5.8/23.5 MB 1.3 MB/s eta 0:00:15
#    ---------- ----------------------------- 6.0/23.5 MB 1.3 MB/s eta 0:00:14
#    ---------- ----------------------------- 6.3/23.5 MB 1.3 MB/s eta 0:00:14
#    ----------- ---------------------------- 6.8/23.5 MB 1.3 MB/s eta 0:00:13
#    ------------ --------------------------- 7.1/23.5 MB 1.4 MB/s eta 0:00:13
#    ------------ --------------------------- 7.6/23.5 MB 1.4 MB/s eta 0:00:12
#    ------------- -------------------------- 7.9/23.5 MB 1.4 MB/s eta 0:00:12
#    ------------- -------------------------- 8.1/23.5 MB 1.4 MB/s eta 0:00:12
#    -------------- ------------------------- 8.4/23.5 MB 1.4 MB/s eta 0:00:12
#    -------------- ------------------------- 8.7/23.5 MB 1.4 MB/s eta 0:00:11
#    --------------- ------------------------ 8.9/23.5 MB 1.4 MB/s eta 0:00:11
#    --------------- ------------------------ 9.2/23.5 MB 1.4 MB/s eta 0:00:11
#    ---------------- ----------------------- 9.7/23.5 MB 1.4 MB/s eta 0:00:11
#    ---------------- ----------------------- 10.0/23.5 MB 1.4 MB/s eta 0:00:10
#    ----------------- ---------------------- 10.2/23.5 MB 1.4 MB/s eta 0:00:10
#    ----------------- ---------------------- 10.5/23.5 MB 1.4 MB/s eta 0:00:10
#    ------------------ --------------------- 11.0/23.5 MB 1.4 MB/s eta 0:00:09
#    ------------------- -------------------- 11.5/23.5 MB 1.4 MB/s eta 0:00:09
#    -------------------- ------------------- 11.8/23.5 MB 1.4 MB/s eta 0:00:09
#    -------------------- ------------------- 12.3/23.5 MB 1.5 MB/s eta 0:00:08
#    --------------------- ------------------ 12.8/23.5 MB 1.5 MB/s eta 0:00:08
#    ---------------------- ----------------- 13.1/23.5 MB 1.5 MB/s eta 0:00:08
#    ----------------------- ---------------- 13.6/23.5 MB 1.5 MB/s eta 0:00:07
#    ------------------------ --------------- 14.2/23.5 MB 1.5 MB/s eta 0:00:07
#    ------------------------ --------------- 14.4/23.5 MB 1.5 MB/s eta 0:00:07
#    ------------------------- -------------- 14.9/23.5 MB 1.5 MB/s eta 0:00:06
#    ------------------------- -------------- 15.2/23.5 MB 1.5 MB/s eta 0:00:06
#    -------------------------- ------------- 15.7/23.5 MB 1.6 MB/s eta 0:00:06
#    --------------------------- ------------ 16.0/23.5 MB 1.6 MB/s eta 0:00:05
#    ---------------------------- ----------- 16.5/23.5 MB 1.6 MB/s eta 0:00:05
#    ---------------------------- ----------- 16.8/23.5 MB 1.6 MB/s eta 0:00:05
#    ---------------------------- ----------- 16.8/23.5 MB 1.6 MB/s eta 0:00:05
#    ----------------------------- ---------- 17.3/23.5 MB 1.5 MB/s eta 0:00:05
#    ----------------------------- ---------- 17.3/23.5 MB 1.5 MB/s eta 0:00:05
#    ----------------------------- ---------- 17.6/23.5 MB 1.5 MB/s eta 0:00:04
#    ------------------------------ --------- 17.8/23.5 MB 1.5 MB/s eta 0:00:04
#    ------------------------------ --------- 18.1/23.5 MB 1.5 MB/s eta 0:00:04
#    ------------------------------- -------- 18.4/23.5 MB 1.5 MB/s eta 0:00:04
#    -------------------------------- ------- 18.9/23.5 MB 1.5 MB/s eta 0:00:04
#    -------------------------------- ------- 19.1/23.5 MB 1.5 MB/s eta 0:00:03
#    -------------------------------- ------- 19.4/23.5 MB 1.5 MB/s eta 0:00:03
#    -------------------------------- ------- 19.4/23.5 MB 1.5 MB/s eta 0:00:03
#    --------------------------------- ------ 19.7/23.5 MB 1.5 MB/s eta 0:00:03
#    --------------------------------- ------ 19.9/23.5 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.2/23.5 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 20.4/23.5 MB 1.5 MB/s eta 0:00:03
#    ----------------------------------- ---- 20.7/23.5 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.0/23.5 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.0/23.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------------ --- 21.5/23.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------------- -- 22.0/23.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------------- -- 22.3/23.5 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 22.5/23.5 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 22.8/23.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  23.1/23.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  23.3/23.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 23.5/23.5 MB 1.5 MB/s  0:00:16
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading build-1.6.1-py3-none-any.whl (31 kB)
# Downloading grpcio-1.83.1-cp314-cp314-win_amd64.whl (5.3 MB)
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.3 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/5.3 MB 2.6 MB/s eta 0:00:02
#    ------- -------------------------------- 1.0/5.3 MB 2.5 MB/s eta 0:00:02
#    --------- ------------------------------ 1.3/5.3 MB 2.2 MB/s eta 0:00:02
#    ------------- -------------------------- 1.8/5.3 MB 2.1 MB/s eta 0:00:02
#    --------------- ------------------------ 2.1/5.3 MB 2.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.4/5.3 MB 1.9 MB/s eta 0:00:02
#    ------------------- -------------------- 2.6/5.3 MB 1.8 MB/s eta 0:00:02
#    --------------------- ------------------ 2.9/5.3 MB 1.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.1/5.3 MB 1.6 MB/s eta 0:00:02
#    --------------------------- ------------ 3.7/5.3 MB 1.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.9/5.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------- -------- 4.2/5.3 MB 1.6 MB/s eta 0:00:01
#    --------------------------------- ------ 4.5/5.3 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.7/5.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 5.0/5.3 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 5.3/5.3 MB 1.6 MB/s  0:00:03
# Downloading kubernetes-36.0.3-py2.py3-none-any.whl (4.6 MB)
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.6 MB 1.2 MB/s eta 0:00:04
#    ------ --------------------------------- 0.8/4.6 MB 1.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.3/4.6 MB 1.3 MB/s eta 0:00:03
#    ------------- -------------------------- 1.6/4.6 MB 1.3 MB/s eta 0:00:03
#    --------------- ------------------------ 1.8/4.6 MB 1.3 MB/s eta 0:00:03
#    ------------------ --------------------- 2.1/4.6 MB 1.3 MB/s eta 0:00:02
#    ------------------ --------------------- 2.1/4.6 MB 1.3 MB/s eta 0:00:02
#    -------------------- ------------------- 2.4/4.6 MB 1.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.6/4.6 MB 1.1 MB/s eta 0:00:02
#    ------------------------ --------------- 2.9/4.6 MB 1.2 MB/s eta 0:00:02
#    --------------------------- ------------ 3.1/4.6 MB 1.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 3.9/4.6 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 4.2/4.6 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 4.5/4.6 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 4.5/4.6 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.6/4.6 MB 1.3 MB/s  0:00:04
# Downloading durationpy-0.11-py3-none-any.whl (4.1 kB)
# Downloading mmh3-5.3.0-cp314-cp314-win_amd64.whl (42 kB)
# Downloading onnxruntime-1.30.0-cp314-cp314-win_amd64.whl (14.7 MB)
#    ---------------------------------------- 0.0/14.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.7 MB 1.8 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/14.7 MB 1.8 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/14.7 MB 1.8 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/14.7 MB 735.5 kB/s eta 0:00:19
#    -- ------------------------------------- 1.0/14.7 MB 830.8 kB/s eta 0:00:17
#    ---- ----------------------------------- 1.6/14.7 MB 1.0 MB/s eta 0:00:13
#    ----- ---------------------------------- 2.1/14.7 MB 1.2 MB/s eta 0:00:11
#    ------- -------------------------------- 2.9/14.7 MB 1.6 MB/s eta 0:00:08
#    --------- ------------------------------ 3.4/14.7 MB 1.7 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.9/14.7 MB 1.8 MB/s eta 0:00:07
#    ----------- ---------------------------- 4.2/14.7 MB 1.7 MB/s eta 0:00:07
#    ------------ --------------------------- 4.5/14.7 MB 1.7 MB/s eta 0:00:06
#    -------------- ------------------------- 5.2/14.7 MB 1.8 MB/s eta 0:00:06
#    --------------- ------------------------ 5.8/14.7 MB 1.9 MB/s eta 0:00:05
#    ---------------- ----------------------- 6.0/14.7 MB 1.9 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.6/14.7 MB 1.9 MB/s eta 0:00:05
#    ------------------ --------------------- 6.8/14.7 MB 1.9 MB/s eta 0:00:05
#    ------------------- -------------------- 7.1/14.7 MB 1.9 MB/s eta 0:00:04
#    -------------------- ------------------- 7.6/14.7 MB 1.8 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.1/14.7 MB 1.9 MB/s eta 0:00:04
#    ---------------------- ----------------- 8.4/14.7 MB 1.9 MB/s eta 0:00:04
#    ------------------------ --------------- 8.9/14.7 MB 1.9 MB/s eta 0:00:03
#    ------------------------- -------------- 9.2/14.7 MB 1.9 MB/s eta 0:00:03
#    -------------------------- ------------- 9.7/14.7 MB 1.9 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.5/14.7 MB 2.0 MB/s eta 0:00:03
#    ------------------------------ --------- 11.0/14.7 MB 2.0 MB/s eta 0:00:02
#    -------------------------------- ------- 11.8/14.7 MB 2.1 MB/s eta 0:00:02
#    -------------------------------- ------- 12.1/14.7 MB 2.0 MB/s eta 0:00:02
#    --------------------------------- ------ 12.3/14.7 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 12.6/14.7 MB 2.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 12.8/14.7 MB 2.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.1/14.7 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.7 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.7 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.7 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.7 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.7 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.7 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 14.7/14.7 MB 1.8 MB/s  0:00:08
# Downloading opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
# Downloading googleapis_common_protos-1.75.3-py3-none-any.whl (306 kB)
# Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
# Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.5.0-cp314-cp314-win_amd64.whl (44 kB)
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Downloading watchfiles-1.2.0-cp314-cp314-win_amd64.whl (288 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pypika, flatbuffers, durationpy, pyproject_hooks, pybase64, overrides, opentelemetry-proto, opentelemetry-api, onnxruntime, oauthlib, mmh3, importlib-resources, grpcio, googleapis-common-protos, bcrypt, watchfiles, requests-oauthlib, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, build, opentelemetry-sdk, kubernetes, opentelemetry-exporter-otlp-proto-grpc, chromadb, langchain-chroma
#
#    - --------------------------------------  1/25 [flatbuffers]
#    --------- ------------------------------  6/25 [opentelemetry-proto]
#    ----------- ----------------------------  7/25 [opentelemetry-api]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    ------------ ---------------------------  8/25 [onnxruntime]
#    -------------- -------------------------  9/25 [oauthlib]
#    -------------- -------------------------  9/25 [oauthlib]
#    ---------------- ----------------------- 10/25 [mmh3]
#    ----------------- ---------------------- 11/25 [importlib-resources]
#    ------------------- -------------------- 12/25 [grpcio]
#    ------------------- -------------------- 12/25 [grpcio]
#    ------------------- -------------------- 12/25 [grpcio]
#    -------------------- ------------------- 13/25 [googleapis-common-protos]
#    -------------------- ------------------- 13/25 [googleapis-common-protos]
#    -------------------- ------------------- 13/25 [googleapis-common-protos]
#    ------------------------ --------------- 15/25 [watchfiles]
#    ---------------------- ---------- 17/25 [opentelemetry-semantic-conventions]
#    ---------------------- ---------- 17/25 [opentelemetry-semantic-conventions]
#    ---------------------- ---------- 17/25 [opentelemetry-semantic-conventions]
#    ---------------------- ---------- 17/25 [opentelemetry-semantic-conventions]
#    ---------------------- ---------- 17/25 [opentelemetry-semantic-conventions]
#    ------------------------------ --------- 19/25 [build]
#    -------------------------------- ------- 20/25 [opentelemetry-sdk]
#    -------------------------------- ------- 20/25 [opentelemetry-sdk]
#    -------------------------------- ------- 20/25 [opentelemetry-sdk]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    --------------------------------- ------ 21/25 [kubernetes]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ------------------------------------ --- 23/25 [chromadb]
#    ---------------------------------------- 25/25 [langchain-chroma]
#
# Successfully installed bcrypt-5.0.0 build-1.6.1 chromadb-1.5.9 durationpy-0.11 flatbuffers-25.12.19 googleapis-common-protos-1.75.3 grpcio-1.83.1 importlib-resources-7.1.0 kubernetes-36.0.3 langchain-chroma-1.1.0 mmh3-5.3.0 oauthlib-3.3.1 onnxruntime-1.30.0 opentelemetry-api-1.44.0 opentelemetry-exporter-otlp-proto-common-1.44.0 opentelemetry-exporter-otlp-proto-grpc-1.44.0 opentelemetry-proto-1.44.0 opentelemetry-sdk-1.44.0 opentelemetry-semantic-conventions-0.65b0 overrides-7.7.0 pybase64-1.5.0 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 watchfiles-1.2.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
    page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
    metadata={"team": "Royal Challengers Bangalore"}
)

doc2 = Document(
    page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
    metadata={"team": "Mumbai Indians"}
)

doc3 = Document(
    page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
    metadata={"team": "Chennai Super Kings"}
)

doc4 = Document(
    page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
    metadata={"team": "Mumbai Indians"}
)

doc5 = Document(
    page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
    metadata={"team": "Chennai Super Kings"}
)

# %%
docs = [doc1 , doc2 , doc3 , doc4 , doc5]

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vector_store = Chroma(
    embedding_function=embeddings,
    persist_directory="my_chroma_db",
    collection_name="sample"
)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 4183.54it/s]

# %%
# add documents :

vector_store.add_documents(docs)
# Out:
# ['2856b0e6-c919-473d-801f-a7557978411f',
#  '33a4f451-b755-432c-82d1-aedbae961eaf',
#  'd3d2a389-66b0-4999-acde-a314eb1ec22f',
#  'e1425609-ec11-44bf-814e-97acbb0e15fb',
#  'da1edd33-6aea-4bd1-aaa5-9f89a8e35088']

# %%
#view documents : 

vector_store.get(include = ['embeddings' , 'documents' , 'metadatas'])
# Out:
# {'ids': ['2856b0e6-c919-473d-801f-a7557978411f',
#   '33a4f451-b755-432c-82d1-aedbae961eaf',
#   'd3d2a389-66b0-4999-acde-a314eb1ec22f',
#   'e1425609-ec11-44bf-814e-97acbb0e15fb',
#   'da1edd33-6aea-4bd1-aaa5-9f89a8e35088'],
#  'embeddings': array([[ 0.00994727,  0.06914337, -0.05147117, ..., -0.03543334,
#           0.01284807,  0.0124829 ],
#         [ 0.00127744,  0.03129853, -0.02375376, ..., -0.00518358,
#          -0.03280612,  0.02737714],
#         [-0.10265914,  0.02650812,  0.02271502, ..., -0.03359744,
#          -0.07984945, -0.01507709],
#         [ 0.02123396, -0.02468546, -0.04494375, ..., -0.10995811,
#           0.00572558,  0.09915376],
#         [ 0.01873978,  0.04382848, -0.04304255, ..., -0.07801619,
#          -0.0784068 , -0.00304187]], shape=(5, 384)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# search doocument : 

vector_store.similarity_search(
    query = 'who among these are a bowler?',
    k = 2
)
# Out:
# [Document(id='e1425609-ec11-44bf-814e-97acbb0e15fb', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='33a4f451-b755-432c-82d1-aedbae961eaf', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.")]

# %%
# search with similarity score : 

vector_store.similarity_search_with_score(
    query = 'who among these are a bowler?',
    k = 2
)
# Out:
# [(Document(id='e1425609-ec11-44bf-814e-97acbb0e15fb', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.9693599343299866),
#  (Document(id='33a4f451-b755-432c-82d1-aedbae961eaf', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   1.1493449211120605)]

# %%
# meta-data filtering : 

vector_store.similarity_search_with_score(
    query = "",
    filter = {'team' : 'Chennai Super Kings'}
)
# Out:
# [(Document(id='d3d2a389-66b0-4999-acde-a314eb1ec22f', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.8436005115509033),
#  (Document(id='da1edd33-6aea-4bd1-aaa5-9f89a8e35088', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   1.890937089920044)]

# %%
# update documents : 

updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='09a39dc6-3ba6-4ea7-927e-fdda591da5e4', document=updated_doc1)

updated_doc1
# Out:
# Document(metadata={'team': 'Royal Challengers Bangalore'}, page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.")

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['2856b0e6-c919-473d-801f-a7557978411f',
#   '33a4f451-b755-432c-82d1-aedbae961eaf',
#   'd3d2a389-66b0-4999-acde-a314eb1ec22f',
#   'e1425609-ec11-44bf-814e-97acbb0e15fb',
#   'da1edd33-6aea-4bd1-aaa5-9f89a8e35088'],
#  'embeddings': array([[ 0.00994727,  0.06914337, -0.05147117, ..., -0.03543334,
#           0.01284807,  0.0124829 ],
#         [ 0.00127744,  0.03129853, -0.02375376, ..., -0.00518358,
#          -0.03280612,  0.02737714],
#         [-0.10265914,  0.02650812,  0.02271502, ..., -0.03359744,
#          -0.07984945, -0.01507709],
#         [ 0.02123396, -0.02468546, -0.04494375, ..., -0.10995811,
#           0.00572558,  0.09915376],
#         [ 0.01873978,  0.04382848, -0.04304255, ..., -0.07801619,
#          -0.0784068 , -0.00304187]], shape=(5, 384)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# delete document
vector_store.delete(ids=['09a39dc6-3ba6-4ea7-927e-fdda591da5e4'])

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['2856b0e6-c919-473d-801f-a7557978411f',
#   '33a4f451-b755-432c-82d1-aedbae961eaf',
#   'd3d2a389-66b0-4999-acde-a314eb1ec22f',
#   'e1425609-ec11-44bf-814e-97acbb0e15fb',
#   'da1edd33-6aea-4bd1-aaa5-9f89a8e35088'],
#  'embeddings': array([[ 0.00994727,  0.06914337, -0.05147117, ..., -0.03543334,
#           0.01284807,  0.0124829 ],
#         [ 0.00127744,  0.03129853, -0.02375376, ..., -0.00518358,
#          -0.03280612,  0.02737714],
#         [-0.10265914,  0.02650812,  0.02271502, ..., -0.03359744,
#          -0.07984945, -0.01507709],
#         [ 0.02123396, -0.02468546, -0.04494375, ..., -0.10995811,
#           0.00572558,  0.09915376],
#         [ 0.01873978,  0.04382848, -0.04304255, ..., -0.07801619,
#          -0.0784068 , -0.00304187]], shape=(5, 384)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}
