# %%
# !pip install -U langchain langchain-core langchain-community \
    pydantic duckduckgo-search langchain-experimental \
    langchain-ollama
# Out:
# Requirement already satisfied: langchain in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.3.18)
# Collecting langchain
#   Downloading langchain-1.4.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: langchain-core in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.6.0)
# Collecting langchain-core
#   Downloading langchain_core-1.6.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: langchain-community in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.4.2)
# Requirement already satisfied: pydantic in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.13.4)
# Collecting pydantic
#   Downloading pydantic-2.13.5-py3-none-any.whl.metadata (110 kB)
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.4.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: langchain-ollama in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.1.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic) (0.8.0)
# Collecting pydantic-core==2.46.5 (from pydantic)
#   Downloading pydantic_core-2.46.5-cp314-cp314-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic) (0.4.4)
# Requirement already satisfied: anyio in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (1.0.9)
# Requirement already satisfied: idna in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.3)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.8.0)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.7.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: click>=8.1.8 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from duckduckgo-search) (8.4.2)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-2.0.1-cp310-abi3-win_amd64.whl.metadata (4.0 kB)
# Requirement already satisfied: lxml>=5.3.0 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from duckduckgo-search) (6.1.2)
# Requirement already satisfied: ollama<1.0.0,>=0.6.1 in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-ollama) (0.6.2)
# Requirement already satisfied: colorama in C:\Users\ANUBHAV\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Downloading langchain-1.4.0-py3-none-any.whl (161 kB)
# Downloading langchain_core-1.6.3-py3-none-any.whl (571 kB)
#    ---------------------------------------- 0.0/571.8 kB ? eta -:--:--
#    ---------------------------------------- 571.8/571.8 kB 6.5 MB/s  0:00:00
# Downloading pydantic-2.13.5-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.5-cp314-cp314-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 10.8 MB/s  0:00:00
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading langchain_experimental-0.4.2-py3-none-any.whl (211 kB)
# Downloading primp-2.0.1-cp310-abi3-win_amd64.whl (6.4 MB)
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    -------------- ------------------------- 2.4/6.4 MB 11.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.4 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.4/6.4 MB 10.7 MB/s  0:00:00
# Installing collected packages: pydantic-core, primp, pydantic, duckduckgo-search, langchain-core, langchain-experimental, langchain
#
#   Attempting uninstall: pydantic-core
#
#     Found existing installation: pydantic_core 2.46.4
#
#     Uninstalling pydantic_core-2.46.4:
#
#       Successfully uninstalled pydantic_core-2.46.4
#
#    ---------------------------------------- 0/7 [pydantic-core]
#   Attempting uninstall: pydantic
#    ---------------------------------------- 0/7 [pydantic-core]
#    ----------- ---------------------------- 2/7 [pydantic]
#     Found existing installation: pydantic 2.13.4
#    ----------- ---------------------------- 2/7 [pydantic]
#     Uninstalling pydantic-2.13.4:
#    ----------- ---------------------------- 2/7 [pydantic]
#       Successfully uninstalled pydantic-2.13.4
#    ----------- ---------------------------- 2/7 [pydantic]
#    ----------- ---------------------------- 2/7 [pydantic]
#    ----------- ---------------------------- 2/7 [pydantic]
#    ----------- ---------------------------- 2/7 [pydantic]
#    ----------- ---------------------------- 2/7 [pydantic]
#    ----------- ---------------------------- 2/7 [pydantic]
#    ----------- ---------------------------- 2/7 [pydantic]
#    ----------- ---------------------------- 2/7 [pydantic]
#    ----------- ---------------------------- 2/7 [pydantic]
#   Attempting uninstall: langchain-core
#    ----------- ---------------------------- 2/7 [pydantic]
#     Found existing installation: langchain-core 1.6.0
#    ----------- ---------------------------- 2/7 [pydantic]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#     Uninstalling langchain-core-1.6.0:
#    ---------------------- ----------------- 4/7 [langchain-core]
#       Successfully uninstalled langchain-core-1.6.0
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------- ----------------- 4/7 [langchain-core]
#    ---------------------------- ----------- 5/7 [langchain-experimental]
#    ---------------------------- ----------- 5/7 [langchain-experimental]
#    ---------------------------- ----------- 5/7 [langchain-experimental]
#    ---------------------------- ----------- 5/7 [langchain-experimental]
#    ---------------------------- ----------- 5/7 [langchain-experimental]
#   Attempting uninstall: langchain
#    ---------------------------- ----------- 5/7 [langchain-experimental]
#     Found existing installation: langchain 1.3.18
#    ---------------------------- ----------- 5/7 [langchain-experimental]
#    ---------------------------------- ----- 6/7 [langchain]
#     Uninstalling langchain-1.3.18:
#    ---------------------------------- ----- 6/7 [langchain]
#       Successfully uninstalled langchain-1.3.18
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------------- 7/7 [langchain]
#
# Successfully installed duckduckgo-search-8.1.1 langchain-1.4.0 langchain-core-1.6.3 langchain-experimental-0.4.2 primp-2.0.1 pydantic-2.13.5 pydantic-core-2.46.5
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %% [markdown]
# ## Built-in Tool - DuckDuckGo Search :

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('top news in india today')

print(results)
# Out:
# Get the latest news today, breaking news, and top news headlines updates from India and around the world. Stay updated on politics, business, sports, entertainment, and more with The Indian Express. Research and investigations point to OpenAI’s agents using multiple internet platforms in order to carry out their own communications — without company authorisation ... AI use is already widespread among 15-year-olds. Across OECD countries, only 14% of students reported never or almost never using AI chatbots for the schoolwork purposes examined ... India’s skilling effort is largely supply-led: training happens where the people are, not where the jobs are 2 days ago - In the state capital, 21-year-old Congress candidate Faiz Hasan won ward 71 of the Jaipur Municipal Corporation while Suman Bhati won from ward 72. From BJP, Neha Sharma, 21, has won from Alwar’s Thanagazi municipality ... World champion D Gukesh will be on board 4 for India at the Chess Olympiad, with Praggnanandhaa, Arjun Erigaisi, and Nihal Sarin on the top three boards. 13 hours ago - National news and headlines from within or around India with live updates on major breaking events from The Hindu. 13 hours ago - India's equity benchmarks logged a third straight weekly gain on Thursday, their longest winning streak in seven months, as crude oil prices fell to pre-Iran-war levels and recent measures to support the rupee and attract overseas inflows ...

# %%
print(search_tool.name)
print(search_tool.description)
print(search_tool.args)
# Out:
# duckduckgo_search
# A wrapper around DuckDuckGo Search. Useful for when you need to answer questions about current events. Input should be a search query.
# {'query': {'description': 'search query to look up', 'title': 'Query', 'type': 'string'}}

# %% [markdown]
# ## Built-in Tool - Shell Tool :

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.invoke('dir')

print(results)
# Out:
# Executing command:
#  dir
#  Volume in drive C is OS
#  Volume Serial Number is B889-BA69
#
#  Directory of C:\Users\ANUBHAV\Program_Folders\AI\GenAI\Agents
#
# 16-09-2026  20:19    <DIR>          .
# 16-09-2026  20:10    <DIR>          ..
# 16-09-2026  20:14    <DIR>          .ipynb_checkpoints
# 16-09-2026  20:12    <DIR>          Datasets
# 16-09-2026  20:19            34,584 tools-in-langchain.ipynb
#                1 File(s)         34,584 bytes
#                4 Dir(s)  362,071,162,880 bytes free

# %% [markdown]
# ## Custom tool :

# %%
from langchain_core.tools import tool

# %%
# Step 1 - create a function

def multiply(a, b):
    """Multiply two numbers"""
    return a*b

# %%
# Step 2 - add type hints

def multiply(a: int, b:int) -> int:
    """Multiply two numbers"""
    return a*b

# %%
# Step 3 - add tool decorator

@tool
def multiply(a: int, b:int) -> int:
    """Multiply two numbers"""
    return a*b

# %%
result = multiply.invoke({"a":3, "b":5})

# %%
print(result)
# Out:
# 15

# %%
print(multiply.name)
print(multiply.description)
print(multiply.args)
# Out:
# multiply
# Multiply two numbers
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}

# %%
print(multiply.args_schema.model_json_schema())
# Out:
# {'description': 'Multiply two numbers', 'properties': {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}, 'required': ['a', 'b'], 'title': 'multiply', 'type': 'object'}

# %% [markdown]
# ## Method 2 - Using StructuredTool :

# %%
from langchain_core.tools import StructuredTool
from pydantic import BaseModel, Field

# %%
from pydantic import BaseModel, Field

class MultiplyInput(BaseModel):
    a: int = Field(description="The first number to multiply")
    b: int = Field(description="The second number to multiply")

# %%
def multiply_func(a: int, b: int) -> int:
    return a * b

# %%
multiply_tool = StructuredTool.from_function(
    func=multiply_func,
    name="multiply",
    description="Multiply two numbers",
    args_schema=MultiplyInput
)

# %%
result = multiply_tool.invoke({'a':3, 'b':3})

# %%
result
# Out:
# 9

# %%
print(result)
print(multiply_tool.name)
print(multiply_tool.description)
print(multiply_tool.args)
# Out:
# 9
# multiply
# Multiply two numbers
# {'a': {'description': 'The first number to multiply', 'title': 'A', 'type': 'integer'}, 'b': {'description': 'The second number to multiply', 'title': 'B', 'type': 'integer'}}

# %% [markdown]
# ## Method 3 - Using BaseTool Class :

# %%
from langchain_core.tools import BaseTool
from typing import Type

# %%
# arg schema using pydantic

class MultiplyInput(BaseModel):
    a: int = Field(description="The first number to add")
    b: int = Field(description="The second number to add")

# %%
class MultiplyTool(BaseTool):
    name: str = "multiply"
    description: str = "Multiply two numbers"

    args_schema: Type[BaseModel] = MultiplyInput

    def _run(self, a: int, b: int) -> int:
        return a * b

# %%
multiply_tool = MultiplyTool()

# %%
result = multiply_tool.invoke({'a':3, 'b':3})
result
# Out:
# 9

# %%
print(multiply_tool.name)
print(multiply_tool.description)

print(multiply_tool.args)
# Out:
# multiply
# Multiply two numbers
# {'a': {'description': 'The first number to add', 'title': 'A', 'type': 'integer'}, 'b': {'description': 'The second number to add', 'title': 'B', 'type': 'integer'}}

# %% [markdown]
# ## Toolkit :

# %%
from langchain_core.tools import tool

# Custom tools
@tool
def add(a: int, b: int) -> int:
    """Add two numbers"""
    return a + b

@tool
def multiply(a: int, b: int) -> int:
    """Multiply two numbers"""
    return a * b

# %%
class MathToolkit:
    def get_tools(self):
        return [add, multiply]

# %%
toolkit = MathToolkit()
tools = toolkit.get_tools()

for tool in tools:
    print(tool.name, "=>", tool.description)
# Out:
# add => Add two numbers
# multiply => Multiply two numbers
